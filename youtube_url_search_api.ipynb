# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime


part='snippet'
channelId='UCZAkjFAaT9gZk-nol6EIX9w'
maxResults=50
key='AIzaSyCF5JTtHHvu2CTPEB3pmqY_4l2-uVlXhYY'
channel_name='neowizard_'
playlistId='PLS8gIc2q83OhM0RTktKDitgZGX5dHo7Vs'

#youtube_search = f'https://www.googleapis.com/youtube/v3/search?part={part}&channelId={channelId}&maxResults={maxResults}&key={key}'
youtube_playlistItems = f'https://www.googleapis.com/youtube/v3/playlistItems?part={part}&playlistId={playlistId}&maxResults={maxResults}&key={key}'

pageToken='&pageToken='
video_base_url = 'https://www.youtube.com/watch?v='
full_url = []
published_date = []
temp_published_date = []

#res = requests.get(youtube_search)
res = requests.get(youtube_playlistItems)
#print(res.json()['nextPageToken'])

# while 1:
      
#     if len(full_url) >= 100:
#         break
    
video_url=[]

#nextPageToken = res.json().get('nextPageToken',None)
#print("nextPageToken",nextPageToken,i)
for data in res.json()['items']:
    #print(data['snippet']['resourceId']['videoId'])
    videoId = data['snippet']['resourceId']['videoId']
    #video_url.append(data['snippet']['resourceId']['videoId'])
    #print(snippet['resourceId']['videoId'])
    #if 'videoId' in data['id']:
    full_url.append(video_base_url+videoId)
    yymmdd = data['snippet']['publishedAt'].split('T')[0].replace('-','')[2:]
    #print("yymmdd",yymmdd)

    temp_published_date.append(yymmdd)
    cnt = temp_published_date.count(yymmdd)
    if cnt:
        yymmdd += f'_{cnt}'

    published_date.append(yymmdd)
    
#     if nextPageToken is not None:
#         res = requests.get(youtube_search+pageToken+nextPageToken)
        
with open('/datadrive/vocoder/autoscript/youtubeurl12.txt','w',encoding='utf-8') as f:
    for i in range(0,len(full_url)):
        f.write(f'{full_url[i]} {channel_name}{published_date[i]}.wav'+'\n')

# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime


part='snippet'
channelId='UCZAkjFAaT9gZk-nol6EIX9w'
maxResults=50
key='AIzaSyCF5JTtHHvu2CTPEB3pmqY_4l2-uVlXhYY'
channel_name='neowizard_'

youtube_search = f'https://www.googleapis.com/youtube/v3/search?part={part}&channelId={channelId}&maxResults={maxResults}&key={key}'
pageToken='&pageToken='
video_base_url = 'https://www.youtube.com/watch?v='
full_url = []
published_date = []
temp_published_date = []

res = requests.get(youtube_search)
res.json()['nextPageToken']

while 1:
    
    if len(full_url) >= 100:
        break
    
    nextPageToken = res.json().get('nextPageToken',None)
    for data in res.json()['items']:
        if 'videoId' in data['id']:
            full_url.append(video_base_url+data['id']['videoId'])
            yymmdd = data['snippet']['publishTime'].split('T')[0].replace('-','')[2:]
        
            temp_published_date.append(yymmdd)
            cnt = temp_published_date.count(yymmdd)
            if cnt:
                yymmdd += f'_{cnt}'

            published_date.append(yymmdd)

                
    if nextPageToken is not None:
        res = requests.get(youtube_search+pageToken+nextPageToken)
       
with open('/datadrive/vocoder/autoscript/youtubeurl7.txt','w',encoding='utf-8') as f:
    for i in range(0,len(full_url)):
        f.write(f'{full_url[i]} {channel_name}{published_date[i]}.wav'+'\n')

# %%
cnt = ['1','1','1','1'].count('2')
if cnt:
    print(f"{cnt}")
print("gg")

# %%
data['snippet']['publishTime']

# %%
published_date

# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime


part='snippet'
channelId='UCZAkjFAaT9gZk-nol6EIX9w'
maxResults=30
key='AIzaSyCF5JTtHHvu2CTPEB3pmqY_4l2-uVlXhYY'
channel_name='neowizard_'

youtube_search = f'https://www.googleapis.com/youtube/v3/search?part={part}&channelId={channelId}&maxResults={maxResults}&key={key}'
pageToken='&pageToken='
video_base_url = 'https://www.youtube.com/watch?v='
full_url = []
published_date = []

res = requests.get(youtube_search)

while 1:
    
    if len(full_url) >= 100:
        break
    
    nextPageToken = res.json()['nextPageToken']
    for data in res.json()['items']:
        if 'videoId' in data['id']:
            full_url.append(video_base_url+data['id']['videoId'])
            published_date.append(data['snippet']['publishTime'].split('T')[0].replace('-','')[2:])
    
    if nextPageToken is not None:
        res = requests.get(youtube_search+pageToken+nextPageToken)

with open('/datadrive/vocoder/autoscript/youtubeurl7.txt','w',encoding='utf-8') as f:
    for i in range(0,len(full_url)):
        f.write(f'{full_url[i]} {channel_name}{published_date[i]}.wav'+'\n')

# %%
len(full_url)

# %%
len(published_date)

# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime


part='snippet'
channelId='UCcviJwrVaorhIFL4csgAz1w'
maxResults=50
key='AIzaSyCF5JTtHHvu2CTPEB3pmqY_4l2-uVlXhYY'
channel_name='kyoboinvest_'

youtube_search = f'https://www.googleapis.com/youtube/v3/search?part={part}&channelId={channelId}&maxResults={maxResults}&key={key}'
pageToken='&pageToken='
video_base_url = 'https://www.youtube.com/watch?v='
full_url = []
published_date = []
temp_published_date = []

res = requests.get(youtube_search)
res.json()['nextPageToken']

while 1:
    
    if len(full_url) >= 100:
        break
    
    nextPageToken = res.json().get('nextPageToken',None)
    for data in res.json()['items']:
        if 'videoId' in data['id']:
            full_url.append(video_base_url+data['id']['videoId'])
            yymmdd = data['snippet']['publishTime'].split('T')[0].replace('-','')[2:]
        
            temp_published_date.append(yymmdd)
            cnt = temp_published_date.count(yymmdd)dd
            if cnt:
                yymmdd += f'_{cnt}'

            published_date.append(yymmdd)

                
    if nextPageToken is not None:
        res = requests.get(youtube_search+pageToken+nextPageToken)
       
with open('/datadrive/vocoder/autoscript/youtubeurl8.txt','w',encoding='utf-8') as f:
    for i in range(0,len(full_url)):
        f.write(f'{full_url[i]} {channel_name}{published_date[i]}.wav'+'\n')

# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime


part='snippet'
channelId='UCZAkjFAaT9gZk-nol6EIX9w'
maxResults=50
key='AIzaSyCF5JTtHHvu2CTPEB3pmqY_4l2-uVlXhYY'
channel_name='kyobo_park_'
playlistId='PLiBe5XMgZpPNlkU6cVBJL4S6FdYduq3OO'

#youtube_search = f'https://www.googleapis.com/youtube/v3/search?part={part}&channelId={channelId}&maxResults={maxResults}&key={key}'
youtube_playlistItems = f'https://www.googleapis.com/youtube/v3/playlistItems?part={part}&playlistId={playlistId}&maxResults={maxResults}&key={key}'

pageToken='&pageToken='
video_base_url = 'https://www.youtube.com/watch?v='
full_url = []
published_date = []
temp_published_date = []

#res = requests.get(youtube_search)
res = requests.get(youtube_playlistItems)
#print(res.json()['nextPageToken'])

# while 1:
      
#     if len(full_url) >= 100:
#         break
    
video_url=[]

#nextPageToken = res.json().get('nextPageToken',None)
#print("nextPageToken",nextPageToken,i)
for data in res.json()['items']:
    #print(data['snippet']['resourceId']['videoId'])
    videoId = data['snippet']['resourceId']['videoId']
    #video_url.append(data['snippet']['resourceId']['videoId'])
    #print(snippet['resourceId']['videoId'])
    #if 'videoId' in data['id']:
    full_url.append(video_base_url+videoId)
    yymmdd = data['snippet']['publishedAt'].split('T')[0].replace('-','')[2:]
    #print("yymmdd",yymmdd)

    temp_published_date.append(yymmdd)
    cnt = temp_published_date.count(yymmdd)
    if cnt:
        yymmdd += f'_{cnt}'

    published_date.append(yymmdd)
    
#     if nextPageToken is not None:
#         res = requests.get(youtube_search+pageToken+nextPageToken)
        
with open('/datadrive/vocoder/autoscript/youtubeurl8.txt','w',encoding='utf-8') as f:
    for i in range(0,len(full_url)):
        f.write(f'{full_url[i]} {channel_name}{published_date[i]}.wav'+'\n')
